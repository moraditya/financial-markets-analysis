# %%
# import relevant libraries

import os
import pandas as pd
from sqlalchemy import create_engine

# %%
# import cleaned_stock_df 

cleaned_data = pd.read_csv(r"C:\Users\adityamxr\Desktop\Projects\stock-market-analysis\data\cleaned_stock_df.csv")

# %%
# verify import
cleaned_data
# Out:
#                       Date        Open        High         Low       Close  \
# 0      2024-06-17 04:00:00   11.220000   11.490000   11.210000   11.440000
# 1      2024-06-18 04:00:00   11.410000   11.500000   11.270000   11.280000
# 2      2024-06-20 04:00:00   11.300000   11.310000   11.190000   11.240000
# 3      2024-06-21 04:00:00   11.220000   11.340000   11.110000   11.200000
# 4      2024-06-24 04:00:00   11.220000   11.340000   11.150000   11.160000
# ...                    ...         ...         ...         ...         ...
# 31545  2024-09-10 04:00:00  191.729996  192.770004  187.820007  191.360001
# 31546  2024-09-11 04:00:00  190.710007  191.149994  186.440002  189.990005
# 31547  2024-09-12 04:00:00  189.979996  190.869995  187.139999  190.710007
# 31548  2024-09-13 04:00:00  190.570007  192.619995  190.139999  191.089996
# 31549  2024-09-16 04:00:00  192.250000  193.750000  191.210007  193.554993
#
#          Volume  Dividends  Stock Splits symbol  moving_avg_7  moving_avg_30  \
# 0      30074100        0.0           0.0    AAL           NaN            NaN
# 1      18841500        0.0           0.0    AAL           NaN            NaN
# 2      21364400        0.0           0.0    AAL           NaN            NaN
# 3      28098100        0.0           0.0    AAL           NaN            NaN
# 4      25666400        0.0           0.0    AAL           NaN            NaN
# ...         ...        ...           ...    ...           ...            ...
# 31545   2675600        0.0           0.0    ZTS    187.614286     184.116000
# 31546   1387900        0.0           0.0    ZTS    188.542858     184.388000
# 31547   1046000        0.0           0.0    ZTS    189.562857     184.743668
# 31548   1725200        0.0           0.0    ZTS    190.100000     185.032668
# 31549    695306        0.0           0.0    ZTS    191.094999     185.464834
#
#        normalized_close  volatility  high_volatility_flag  price_outlier  \
# 0              1.000000    0.280000                 False          False
# 1              0.926606    0.230000                 False          False
# 2              0.908257    0.120001                 False          False
# 3              0.889908    0.230000                 False          False
# 4              0.871560    0.190001                 False          False
# ...                 ...         ...                   ...            ...
# 31545          0.915491    4.949997                  True          False
# 31546          0.862746    4.709991                  True          False
# 31547          0.890466    3.729996                  True          False
# 31548          0.905096    2.479996                 False          False
# 31549          1.000000    2.539993                 False          False
#
#                       Security  GICS Sector   GICS Sub-Industry  \
# 0      American Airlines Group  Industrials  Passenger Airlines
# 1      American Airlines Group  Industrials  Passenger Airlines
# 2      American Airlines Group  Industrials  Passenger Airlines
# 3      American Airlines Group  Industrials  Passenger Airlines
# 4      American Airlines Group  Industrials  Passenger Airlines
# ...                        ...          ...                 ...
# 31545                   Zoetis  Health Care     Pharmaceuticals
# 31546                   Zoetis  Health Care     Pharmaceuticals
# 31547                   Zoetis  Health Care     Pharmaceuticals
# 31548                   Zoetis  Health Care     Pharmaceuticals
# 31549                   Zoetis  Health Care     Pharmaceuticals
#
#         Headquarters Location
# 0           Fort Worth, Texas
# 1           Fort Worth, Texas
# 2           Fort Worth, Texas
# 3           Fort Worth, Texas
# 4           Fort Worth, Texas
# ...                       ...
# 31545  Parsippany, New Jersey
# 31546  Parsippany, New Jersey
# 31547  Parsippany, New Jersey
# 31548  Parsippany, New Jersey
# 31549  Parsippany, New Jersey
#
# [31550 rows x 19 columns]

# %%
# fetch PostgreSQL credentials from environment variables
postgres_user = os.getenv('POSTGRES_USER')
postgres_pass = os.getenv('POSTGRES_PASSWORD')
postgres_db = os.getenv('POSTGRES_DB')
postgres_host = os.getenv('POSTGRES_HOST')
postgres_port = os.getenv('POSTGRES_PORT')

# %%
# create a connection to PostgreSQL using the environment variables
engine = create_engine(f'postgresql://{postgres_user}:{postgres_pass}@{postgres_host}:{postgres_port}/{postgres_db}')

# %%
# load the cleaned dataframe into postgresql
cleaned_data.to_sql('stock_data', engine, if_exists='replace', index =False)
# Out:
# 550
